# %%
from flask import Flask, render_template, request, redirect, url_for
from IPython.display import display, Javascript

app = Flask(__name__)

# Store registered users in memory (for simplicity)
users = []

# Route for the Home page
@app.route('/')
def home():
    return render_template('Home_Page.html')

# Route for the About page
@app.route('/about')
def about():
    return render_template('About.html')

# Route for User Registration page
@app.route('/register', methods=['GET', 'POST'])
def register():
    if request.method == 'POST':
        username = request.form['username']
        password = request.form['password']
        users.append({'username': username, 'password': password})
        return redirect(url_for('home'))
    return render_template('Registration_Form.html')

# Route for Data Display page
@app.route('/login')
def login():
    return render_template('Login.html')

# Function to run the Flask app
def run_flask():
    app.run(host='0.0.0.0', port=5000)

# Start the Flask application
run_flask()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.128.126.54:5000
# Press CTRL+C to quit
# 10.128.126.54 - - [04/Nov/2025 13:34:56] "GET / HTTP/1.1" 200 -
# 10.128.126.54 - - [04/Nov/2025 13:34:56] "GET /static/images/hospital.jpg HTTP/1.1" 200 -
